# %%
# librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from mpl_toolkits.basemap import Basemap


import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.ar_model import ARResults

# %%
df = pd.read_csv('meteorite-landings.csv')
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
df.shape
# Out:
# (45716, 10)

# %%
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass           float64
# fall            object
# year           float64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
# name           45716 non-null object
# id             45716 non-null int64
# nametype       45716 non-null object
# recclass       45716 non-null object
# mass           45585 non-null float64
# fall           45716 non-null object
# year           45428 non-null float64
# reclat         38401 non-null float64
# reclong        38401 non-null float64
# GeoLocation    38401 non-null object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.5+ MB

# %% [markdown]
# # Cleaning

# %%
df.isna().sum()
# Out:
# name              0
# id                0
# nametype          0
# recclass          0
# mass            131
# fall              0
# year            288
# reclat         7315
# reclong        7315
# GeoLocation    7315
# dtype: int64

# %% [markdown]
# ### Year

# %%
#filter to drop invalid values
df = df[(df.year >=860) & (df.year <=2016)]
#transform year (float to int)
df['year'] = pd.to_numeric(df.year,downcast='integer')

# %% [markdown]
# ### Mass

# %%
#drop NaN
df = df[np.isfinite(df['mass'])]

# %% [markdown]
# ### Longitude Lattitude

# %%
#filter to drop invalid values
df = df[(df.reclat != 0.0) & (df.reclong != 0.0)]
df = df[(df.reclong <=180) & (df.reclong >=-180)]

# %% [markdown]
# ### Fall

# %%
df.fall.value_counts(normalize=True)
# Out:
# Found    0.966472
# Fell     0.033528
# Name: fall, dtype: float64

# %%
df = pd.get_dummies(df, columns=['fall'])

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  year    reclat    reclong  \
# 0    Aachen    1    Valid           L5      21.0  1880  50.77500    6.08333
# 1    Aarhus    2    Valid           H6     720.0  1951  56.18333   10.23333
# 2      Abee    6    Valid          EH4  107000.0  1952  54.21667 -113.00000
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976  16.88333  -99.90000
# 4   Achiras  370    Valid           L6     780.0  1902 -33.16667  -64.95000
#
#                 GeoLocation  fall_Fell  fall_Found
# 0     (50.775000, 6.083330)          1           0
# 1    (56.183330, 10.233330)          1           0
# 2  (54.216670, -113.000000)          1           0
# 3   (16.883330, -99.900000)          1           0
# 4  (-33.166670, -64.950000)          1           0

# %% [markdown]
# # Descriptive stats and visualisation

# %%
df.corr()
# Out:
#                   id      mass      year    reclat   reclong  fall_Fell  \
# id          1.000000 -0.014712  0.238671  0.056363 -0.183254  -0.053076
# mass       -0.014712  1.000000 -0.124215  0.036230 -0.027062   0.007814
# year        0.238671 -0.124215  1.000000 -0.229160  0.197239  -0.508986
# reclat      0.056363  0.036230 -0.229160  1.000000 -0.534294   0.310099
# reclong    -0.183254 -0.027062  0.197239 -0.534294  1.000000  -0.118656
# fall_Fell  -0.053076  0.007814 -0.508986  0.310099 -0.118656   1.000000
# fall_Found  0.053076 -0.007814  0.508986 -0.310099  0.118656  -1.000000
#
#             fall_Found
# id            0.053076
# mass         -0.007814
# year          0.508986
# reclat       -0.310099
# reclong       0.118656
# fall_Fell    -1.000000
# fall_Found    1.000000

# %%
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True)
plt.show()

'''
it seems a positive correlation between year & found 
    0.51 : weak correlation

but a nagative correlation between year & fall
    - 0.51 : weak correlation

mass ? no correlation after remove outliers
'''
# Out:
# '\nit seems a positive correlation between year & found \n    0.51 : weak correlation\n\nbut a nagative correlation between year & fall\n    - 0.51 : weak correlation\n\nmass ? no correlation after remove outliers\n'

# %% [markdown]
# ### Mass

# %%
df.boxplot('mass')

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out
remove_outlier(df,'mass').boxplot('mass')

# %% [markdown]
# ### Fell & Found

# %%
df[['fall_Found','fall_Fell']].agg('sum').plot.bar()

# %%
# MAP OF ALL IMPACTS
fig, ax = plt.subplots(figsize = (15, 10))
map = Basemap(projection='cyl')
map.drawmapboundary(fill_color='w')
map.drawcoastlines(linewidth=0.5)
map.drawmeridians(range(0, 360, 20),linewidth=0.1)
map.drawparallels([-66.56083,-23.5,0.0,23.5,66.56083], linewidth=0.6) 
#plotting equator and tropics and polar circles

x1, y1 = map(df.reclong,df.reclat)

map.scatter(x1, y1, marker='.',alpha=0.25,c='green',edgecolor='None')
plt.title('Map of all impacts', fontsize=15)
plt.show()

# %%
# MAP OF FOUND OR FELL METEORITES
fig, ax = plt.subplots(figsize = (20, 15))
map = Basemap(projection='cyl')
map.drawmapboundary(fill_color='w')
map.drawcoastlines(linewidth=0.5)
map.drawmeridians(range(0, 360, 20),linewidth=0.1)
map.drawparallels([-66.56083,-23.5,0.0,23.5,66.56083], linewidth=0.6) 
#plotting equator and tropics and polar circles

x1, y1 = map(df[df.fall_Fell == 1].reclong,df[df.fall_Fell == 1].reclat)
map.scatter(x1, y1, marker='.',alpha=0.25,c='green',edgecolor='None')

x1, y1 = map(df[df.fall_Found == 1].reclong,df[df.fall_Found == 1].reclat)
map.scatter(x1, y1, marker='.',alpha=0.25,c='red',edgecolor='None')
#plt.legend()
plt.title('Map of all impacts', fontsize=15)
plt.show()

# %% [markdown]
# ### mass

# %%
#group mass from = https://en.wikipedia.org/wiki/Meteorite_classification
#dfmass = df.copy()

# %%
df.recclass.replace(to_replace=['Acapulcoite', 'Acapulcoite/Lodranite', 
                                    'Acapulcoite/lodranite','Lodranite','Lodranite-an',
                                    'Winonaite','Achondrite-prim'],
                    value='Achondrite_prim',inplace=True)

# %%
df.recclass.replace(to_replace=['Angrite', 'Aubrite','Aubrite-an','Ureilite',
                                     'Ureilite-an','Ureilite-pmict','Brachinite','Diogenite',
                                     'Diogenite-an', 'Diogenite-olivine', 'Diogenite-pm',
                                     'Eucrite', 'Eucrite-Mg rich', 'Eucrite-an', 'Eucrite-br',
                                     'Eucrite-cm','Eucrite-mmict', 'Eucrite-pmict',
                                     'Eucrite-unbr','Howardite'],
                         value='Achondrite_aste',inplace=True)

# %%
df.recclass.replace(to_replace=['Lunar', 'Lunar (anorth)', 'Lunar (bas. breccia)',
                                    'Lunar (bas/anor)', 'Lunar (bas/gab brec)', 
                                    'Lunar (basalt)','Lunar (feldsp. breccia)', 
                                    'Lunar (gabbro)', 'Lunar (norite)'],
                        value='Lunar',inplace=True)

# %%
df.recclass.replace(to_replace=['Martian', 'Martian (OPX)','Martian (chassignite)',
                                    'Martian (nakhlite)','Martian (shergottite)'],
                        value='Martian',inplace=True)

# %%
df.recclass.replace(to_replace=['C','C2','C4','C4/5','C6','C1-ung', 'C1/2-ung','C2-ung',
                                    'C3-ung', 'C3/4-ung','C4-ung','C5/6-ung','CB', 'CBa',
                                    'CBb', 'CH/CBb', 'CH3', 'CH3 ', 'CI1', 'CK', 'CK3',
                                    'CK3-an', 'CK3.8', 'CK3/4', 'CK4', 'CK4-an', 'CK4/5',
                                    'CK5','CK5/6', 'CK6', 'CM', 'CM-an', 'CM1', 'CM1/2',
                                    'CM2', 'CM2-an','CO3', 'CO3 ', 'CO3.0', 'CO3.1', 'CO3.2',
                                    'CO3.3', 'CO3.4', 'CO3.5','CO3.6', 'CO3.7', 'CO3.8', 'CR',
                                    'CR-an', 'CR1', 'CR2', 'CR2-an','CV2', 'CV3', 'CV3-an'],
                        value='Chondrite_carbon',inplace=True)

# %%
df.recclass.replace(to_replace=['OC', 'OC3','H', 'H(5?)', 'H(?)4', 'H(L)3', 'H(L)3-an',
                                     'H-an','H-imp melt','H-melt rock', 'H-metal', 'H/L3',
                                     'H/L3-4', 'H/L3.5','H/L3.6', 'H/L3.7', 'H/L3.9', 'H/L4',
                                     'H/L4-5', 'H/L4/5', 'H/L5','H/L6', 'H/L6-melt rock',
                                     'H/L~4', 'H3', 'H3 ', 'H3-4', 'H3-5','H3-6', 'H3-an',
                                     'H3.0', 'H3.0-3.4', 'H3.1', 'H3.10', 'H3.2','H3.2-3.7',
                                     'H3.2-6', 'H3.2-an', 'H3.3', 'H3.4', 'H3.4-5','H3.4/3.5',
                                     'H3.5', 'H3.5-4', 'H3.6', 'H3.6-6', 'H3.7', 'H3.7-5',
                                     'H3.7-6', 'H3.7/3.8', 'H3.8', 'H3.8-4', 'H3.8-5', 'H3.8-6',
                                     'H3.8-an', 'H3.8/3.9', 'H3.8/4', 'H3.9', 'H3.9-5', 
                                     'H3.9-6','H3.9/4', 'H3/4', 'H4', 'H4 ', 'H4(?)', 'H4-5',
                                     'H4-6', 'H4-an','H4/5', 'H4/6', 'H5', 'H5 ', 'H5-6', 
                                     'H5-7', 'H5-an','H5-melt breccia', 'H5/6', 'H6', 'H6 ',
                                     'H6-melt breccia', 'H6/7','H7', 'H?','H~4', 'H~4/5', 'H~5',
                                     'H~6','L', 'L(?)3','L(H)3', 'L(LL)3', 'L(LL)3.05',
                                     'L(LL)3.5-3.7', 'L(LL)5', 'L(LL)6','L(LL)~4', 'L-imp melt',
                                     'L-melt breccia', 'L-melt rock', 'L-metal','L/LL',
                                     'L/LL(?)3', 'L/LL-melt rock', 'L/LL3', 'L/LL3-5',
                                     'L/LL3-6','L/LL3.10', 'L/LL3.2', 'L/LL3.4', 'L/LL3.5',
                                     'L/LL3.6/3.7', 'L/LL4','L/LL4-6', 'L/LL4/5', 'L/LL5',
                                     'L/LL5-6', 'L/LL5/6', 'L/LL6','L/LL6-an', 'L/LL~4',
                                     'L/LL~5', 'L/LL~6', 'L3', 'L3-4', 'L3-5','L3-6', 'L3-7',
                                     'L3.0', 'L3.0-3.7', 'L3.0-3.9', 'L3.05', 'L3.1','L3.10',
                                     'L3.2', 'L3.2-3.5', 'L3.2-3.6', 'L3.3', 'L3.3-3.5',
                                     'L3.3-3.6', 'L3.3-3.7', 'L3.4', 'L3.4-3.7', 'L3.5',
                                     'L3.5-3.7','L3.5-3.8', 'L3.5-3.9', 'L3.5-5', 'L3.6',
                                     'L3.6-4', 'L3.7','L3.7-3.9', 'L3.7-4', 'L3.7-6',
                                     'L3.7/3.8', 'L3.8', 'L3.8-5','L3.8-6', 'L3.8-an', 'L3.9',
                                     'L3.9-5', 'L3.9-6', 'L3.9/4', 'L3/4','L4', 'L4 ', 'L4-5',
                                     'L4-6', 'L4-an', 'L4-melt rock', 'L4/5', 'L5','L5 ',
                                     'L5-6', 'L5-7', 'L5/6', 'L6', 'L6 ', 'L6-melt breccia',
                                     'L6-melt rock', 'L6/7', 'L7', 'LL', 'LL(L)3', 
                                     'LL-melt rock', 'LL3','LL3-4', 'LL3-5', 'LL3-6', 'LL3.0',
                                     'LL3.00', 'LL3.1', 'LL3.1-3.5','LL3.10', 'LL3.15', 'LL3.2',
                                     'LL3.3', 'LL3.4', 'LL3.5', 'LL3.6','LL3.7', 'LL3.7-6',
                                     'LL3.8', 'LL3.8-6', 'LL3.9', 'LL3.9/4', 'LL3/4','LL4',
                                     'LL4-5', 'LL4-6', 'LL4/5', 'LL4/6', 'LL5', 'LL5-6',
                                     'LL5-7','LL5/6', 'LL6', 'LL6 ', 'LL6(?)', 'LL6/7', 'LL7',
                                     'LL7(?)','LL<3.5', 'LL~3', 'LL~4', 'LL~4/5', 'LL~5',
                                     'LL~6','L~3', 'L~4', 'L~5', 'L~6','Relict H','Relict OC'],
                         value='Chondrite_ordin',inplace=True)

# %%
df.recclass.replace(to_replace=['EH','EH-imp melt', 'EH3', 'EH3/4-an', 'EH4', 'EH4/5',
                                     'EH5', 'EH6','EH6-an', 'EH7', 'EH7-an', 'EL3', 'EL3/4',
                                     'EL4', 'EL4/5', 'EL5','EL6', 'EL6 ', 'EL6/7', 'EL7','E',
                                     'E3','E4', 'E5','E6'],
                         value='Chondrite_enst',inplace=True)

# %%
df.recclass.replace(to_replace=['K', 'K3','R', 'R3', 'R3-4', 'R3-5', 'R3-6', 'R3.4', 
                                    'R3.5-6','R3.6', 'R3.7', 'R3.8', 'R3.8-5', 'R3.8-6', 'R3.9',
                                    'R3/4', 'R4','R4/5', 'R5', 'R6'],
                        value='Chondrite_other',inplace=True)

# %%
df.recclass.replace(to_replace=['Pallasite', 'Pallasite, PES','Pallasite, PMG',
                                    'Pallasite, PMG-an', 'Pallasite, ungrouped','Pallasite?'],
                        value='Pallasite',inplace=True)

# %%
df.recclass.replace(to_replace=['Mesosiderite', 'Mesosiderite-A','Mesosiderite-A1',
                                    'Mesosiderite-A2', 'Mesosiderite-A3','Mesosiderite-A3/4',
                                    'Mesosiderite-A4', 'Mesosiderite-B','Mesosiderite-B1',
                                    'Mesosiderite-B2', 'Mesosiderite-B4','Mesosiderite-C',
                                    'Mesosiderite-C2', 'Mesosiderite-an','Mesosiderite?'],
                        value='Mesosiderite',inplace=True)

# %%
df.recclass.replace(to_replace=['Iron, IC', 'Iron, IC-an', 'Iron, IIAB', 'Iron, IIAB-an',
                                    'Iron, IIC', 'Iron, IID', 'Iron, IID-an','Iron, IIF', 
                                    'Iron, IIG','Iron, IIIAB', 'Iron, IIIAB-an', 'Iron, IIIAB?',
                                    'Iron, IIIE','Iron, IIIE-an', 'Iron, IIIF', 'Iron, IVA',
                                    'Iron, IVA-an','Iron, IVB'],
                        value='Magmatic',inplace=True)

# %%
df.recclass.replace(to_replace=['Iron, IAB complex', 'Iron, IAB-MG','Iron, IAB-an',
                                    'Iron, IAB-sHH','Iron, IAB-sHL', 'Iron, IAB-sLH',
                                    'Iron, IAB-sLL', 'Iron, IAB-sLM','Iron, IAB-ung',
                                    'Iron, IAB?','Iron, IIE','Iron, IIE-an', 'Iron, IIE?'],
                        value='Non_magmatic',inplace=True)

# %%
df.recclass.replace(to_replace=['Iron','Iron?','Relict iron','Chondrite-fusion crust',
                                    'Fusion crust','Impact melt breccia','Enst achon-ung',
                                    'Iron, ungrouped','Stone-uncl', 'Stone-ung','Unknown',
                                    'Achondrite-ung','Chondrite-ung','Enst achon','E-an',
                                    'E3-an',  'E5-an'],
                        value='Unknown-Ungrouped',inplace=True)

# %%
df.recclass.value_counts().plot.barh()

# %%
df.head()
# Out:
#        name   id nametype         recclass      mass  year    reclat  \
# 0    Aachen    1    Valid  Chondrite_ordin      21.0  1880  50.77500
# 1    Aarhus    2    Valid  Chondrite_ordin     720.0  1951  56.18333
# 2      Abee    6    Valid   Chondrite_enst  107000.0  1952  54.21667
# 3  Acapulco   10    Valid  Achondrite_prim    1914.0  1976  16.88333
# 4   Achiras  370    Valid  Chondrite_ordin     780.0  1902 -33.16667
#
#      reclong               GeoLocation  fall_Fell  fall_Found
# 0    6.08333     (50.775000, 6.083330)          1           0
# 1   10.23333    (56.183330, 10.233330)          1           0
# 2 -113.00000  (54.216670, -113.000000)          1           0
# 3  -99.90000   (16.883330, -99.900000)          1           0
# 4  -64.95000  (-33.166670, -64.950000)          1           0

# %% [markdown]
# dfrec = df[df.recclass == 'Chondrite_ordin']
# dfrec.recclass.value_counts()

# %% [markdown]
# # logistic regression
# possible to predict where the meteorits found depending to year

# %%
dftest = df.copy()
dflog = dftest.copy()

# %%
from sklearn.linear_model import LogisticRegression

# %%
#df1 = pd.get_dummies(df1, columns=['recclass'])

# %%
dflog.head()
# Out:
#        name   id nametype         recclass      mass  year    reclat  \
# 0    Aachen    1    Valid  Chondrite_ordin      21.0  1880  50.77500
# 1    Aarhus    2    Valid  Chondrite_ordin     720.0  1951  56.18333
# 2      Abee    6    Valid   Chondrite_enst  107000.0  1952  54.21667
# 3  Acapulco   10    Valid  Achondrite_prim    1914.0  1976  16.88333
# 4   Achiras  370    Valid  Chondrite_ordin     780.0  1902 -33.16667
#
#      reclong               GeoLocation  fall_Fell  fall_Found
# 0    6.08333     (50.775000, 6.083330)          1           0
# 1   10.23333    (56.183330, 10.233330)          1           0
# 2 -113.00000  (54.216670, -113.000000)          1           0
# 3  -99.90000   (16.883330, -99.900000)          1           0
# 4  -64.95000  (-33.166670, -64.950000)          1           0

# %%
dflog.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'year', 'reclat',
#        'reclong', 'GeoLocation', 'fall_Fell', 'fall_Found'],
#       dtype='object')

# %%
dflog = dftest.drop('fall_Fell',axis=1).drop('recclass',axis=1).drop(
    'nametype',axis=1).drop('id',axis=1).drop('name',axis=1)
dflog[df.fall_Found == 0].shape
# Out:
# (1063, 6)

# %%
sns.countplot(x='fall_Found',data=dflog,palette="Set2")

# %% [markdown]
# This is a count plot that shows the number of meteorite who found which is our target variable.

# %%
from sklearn.model_selection import train_test_split
dflog_test = dflog.copy()
X_train, X_test, y_train, y_test = train_test_split(dflog_test.drop('fall_Found',axis=1), 
                                                    dflog_test['fall_Found'], test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-e9f1f5b66254> in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 logmodel = LogisticRegression()
# ----> 3 logmodel.fit(X_train,y_train)
#       4 predictions = logmodel.predict(X_test)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: '(-72.774444, 75.321667)'

# %%
y_train.value_counts()
# Out:
# 1    21444
# 0      749
# Name: fall_Found, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.plotting import plot_decision_regions, plot_confusion_matrix
from matplotlib import pyplot as plt

# %%
X_train, X_test, y_train, y_test = train_test_split(dflog_test.drop('fall_Found',axis=1), 
                                                    dflog_test['fall_Found'], test_size=0.30, 
                                                    random_state=101)

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
#predictions = logmodel.predict(X_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-69ec18b0546a> in <module>
#       1 logmodel = LogisticRegression()
# ----> 2 logmodel.fit(X_train,y_train)
#       3 #predictions = logmodel.predict(X_test)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: '(-10.059440, 33.395000)'

# %%
dfsamp = dflog.copy()

# %%
dfsamp.fall_Found.value_counts()
# Out:
# 1    30642
# 0     1063
# Name: fall_Found, dtype: int64

# %%
dfsamp = dfsamp[dfsamp['fall_Found'] == 1]

# %%
dfsamp = dfsamp.sample(n=3500, weights='fall_Found', random_state=1)

# %%
dfsamp.shape
# Out:
# (3500, 6)

# %%
dfsamp2 = dflog.copy()

# %%
dfsamp2.fall_Found.value_counts()
# Out:
# 1    30642
# 0     1063
# Name: fall_Found, dtype: int64

# %%
dfsamp2 = dfsamp2[dfsamp2['fall_Found'] == 0]

# %%
dfsamp = dfsamp.append(dfsamp2)

# %%
dfsamp.fall_Found.value_counts()
# Out:
# 1    3500
# 0    1063
# Name: fall_Found, dtype: int64

# %%
dfsamp = dfsamp.reset_index()
dfsamp = dfsamp.drop('index',axis=1)

# %%
from sklearn.utils import shuffle
dfsamp = shuffle(dfsamp)

# %%
X = dfsamp # Features
y = dfsamp.fall_Found # Target variable

# %%
X_train,X_test = train_test_split(dfsamp,test_size=0.3, random_state=0)
print(len(X_train), len(X_test))
# Out:
# 3194 1369

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel_fit = logmodel.fit(X_train,X_test)
#predictions = logmodel.predict(X_test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-b868d325b3cd> in <module>
#       1 from sklearn.linear_model import LogisticRegression
#       2 logmodel = LogisticRegression()
# ----> 3 logmodel_fit = logmodel.fit(X_train,X_test)
#       4 #predictions = logmodel.predict(X_test)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: '(-10.059440, 33.395000)'

# %%
X=[i for i in data_final_vars if i not in y]
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
rfe = RFE(logreg, 20)
rfe = rfe.fit(os_data_X, os_data_y.values.ravel())
print(rfe.support_)
print(rfe.ranking_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-715890d1220b> in <module>
#       1
# ----> 2 X=[i for i in data_final_vars if i not in y]
#       3 from sklearn.feature_selection import RFE
#       4 from sklearn.linear_model import LogisticRegression
#       5 logreg = LogisticRegression()
#
# NameError: name 'data_final_vars' is not defined

# %%
import statsmodels.api as sm
logit_model=sm.Logit(X_train.fall_Found,X_train.iloc[:,:-1])
result=logit_model.fit()
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-2cdb130b9c31> in <module>
#       1 import statsmodels.api as sm
# ----> 2 logit_model=sm.Logit(X_train.fall_Found,X_train.iloc[:,:-1])
#       3 result=logit_model.fit()
#       4 print(result.summary())
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, **kwargs)
#     416
#     417     def __init__(self, endog, exog, **kwargs):
# --> 418         super(BinaryModel, self).__init__(endog, exog, **kwargs)
#     419         if (not issubclass(self.__class__, MultinomialModel) and
#     420                 not np.all((self.endog >= 0) & (self.endog <= 1))):
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, **kwargs)
#     169     """
#     170     def __init__(self, endog, exog, **kwargs):
# --> 171         super(DiscreteModel, self).__init__(endog, exog, **kwargs)
#     172         self.raise_on_perfect_prediction = True
#     173
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
#
# /anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     472         exog = exog if exog is None else np.asarray(exog)
#     473         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 474             raise ValueError("Pandas data cast to numpy dtype of object. "
#     475                              "Check input data with np.asarray(data).")
#     476         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
X_train.year.value_counts()
# Out:
# 1979    238
# 1988    178
# 2000    141
# 2003    140
# 1999    137
# 1990    134
# 1986    115
# 2001    108
# 2006    103
# 2002    100
# 1997     98
# 1993     79
# 1991     68
# 1987     67
# 1994     65
# 1995     54
# 1984     52
# 1996     48
# 2011     47
# 1981     43
# 1975     39
# 1998     39
# 1974     39
# 1985     38
# 1992     37
# 1983     34
# 2004     32
# 1977     30
# 2008     27
# 2009     25
#        ...
# 1490      1
# 1830      1
# 1621      1
# 1854      1
# 1801      1
# 1931      1
# 1885      1
# 1849      1
# 1847      1
# 1839      1
# 1833      1
# 1827      1
# 1819      1
# 1817      1
# 1813      1
# 1805      1
# 1795      1
# 1862      1
# 1785      1
# 1775      1
# 1751      1
# 1741      1
# 1671      1
# 1637      1
# 1583      1
# 1491      1
# 1399      1
# 1894      1
# 1870      1
# 860       1
# Name: year, Length: 225, dtype: int64

# %%
def gr_year(i):
    if i >= 2010 :
        i = '2010_2020'
    elif (i >= 1980) & (i <= 1989):
        i = "1980s"
    elif (i >= 1990) & (i <= 1999):
        i = "1990s"
    elif (i >= 2000) & (i <= 2009) :
        i = "2000s"
    elif i < 1980 : 
        i = 'bf_1970'
    return i

# %%
dfsamp['year'] = dfsamp['year'].apply(lambda x: gr_year(x))

# %%
dfsamp = pd.get_dummies(dfsamp, columns=['year'])

# %%
dfsamp = dfsamp.drop('year_bf_1970',axis=1)

# %%
dfsamp
# Out:
#           mass     reclat     reclong                GeoLocation  fall_Found  \
# 3810   4162.00  12.850000   11.033330     (12.850000, 11.033330)           0
# 3707     78.40  35.950000  -97.583330    (35.950000, -97.583330)           0
# 1492    591.00  27.151330   16.045000     (27.151330, 16.045000)           1
# 1082      4.61 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 3808    380.00  27.883330   68.533330     (27.883330, 68.533330)           0
# 2551      8.58 -86.366670  -70.000000   (-86.366670, -70.000000)           1
# 3689   6000.00  53.700000   30.100000     (53.700000, 30.100000)           0
# 840      25.61 -85.633330  -68.700000   (-85.633330, -68.700000)           1
# 65        3.60 -84.575870  162.566600   (-84.575870, 162.566600)           1
# 2425     13.10 -76.688060  159.360840   (-76.688060, 159.360840)           1
# 3995   2800.00  47.083330    1.750000      (47.083330, 1.750000)           0
# 159     439.40 -84.266110  161.316670   (-84.266110, 161.316670)           1
# 1040   2576.00  34.533330 -101.183330   (34.533330, -101.183330)           1
# 60        0.84 -72.775000   75.339722    (-72.775000, 75.339722)           1
# 2180    328.29 -72.000000   26.000000    (-72.000000, 26.000000)           1
# 4098   6380.00  35.568330  133.220000    (35.568330, 133.220000)           0
# 3405    869.00  27.666670    4.283330      (27.666670, 4.283330)           1
# 4145  23200.00  13.733330  100.083330    (13.733330, 100.083330)           0
# 2082     26.11 -72.952750  160.498330   (-72.952750, 160.498330)           1
# 4037   3500.00  47.850000    0.483330      (47.850000, 0.483330)           0
# 2267     18.00 -30.366670  130.083330   (-30.366670, 130.083330)           1
# 2653     19.10 -76.283410  156.462790   (-76.283410, 156.462790)           1
# 1288     14.00 -79.683330  159.750000   (-79.683330, 159.750000)           1
# 4449   3000.00  14.250000    1.533330      (14.250000, 1.533330)           0
# 586     341.00  18.962170   54.189670     (18.962170, 54.189670)           1
# 4558   2900.00  39.666670  122.983330    (39.666670, 122.983330)           0
# 771       2.55 -72.952030  160.509390   (-72.952030, 160.509390)           1
# 48       18.00 -76.267290  156.442190   (-76.267290, 156.442190)           1
# 182      11.90 -76.275950  156.469860   (-76.275950, 156.469860)           1
# 3815    670.00  52.200000    6.866670      (52.200000, 6.866670)           0
# ...        ...        ...         ...                        ...         ...
# 609       1.27 -72.784440   75.280280    (-72.784440, 75.280280)           1
# 818      99.10 -84.000000  168.000000   (-84.000000, 168.000000)           1
# 3413  13000.00  36.850000  -82.450000    (36.850000, -82.450000)           1
# 2555     21.90 -86.366670  -70.000000   (-86.366670, -70.000000)           1
# 3229      1.60 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 4361  20000.00  21.683890   79.500830     (21.683890, 79.500830)           0
# 2192      3.30 -76.281980  156.427840   (-76.281980, 156.427840)           1
# 2654     22.10 -84.000000  168.000000   (-84.000000, 168.000000)           1
# 2837     10.50 -84.000000  168.000000   (-84.000000, 168.000000)           1
# 283      83.90 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 4159   6189.00  47.525000   10.808330     (47.525000, 10.808330)           0
# 593     569.95 -72.000000   26.000000    (-72.000000, 26.000000)           1
# 2586      1.98 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 1628      9.16 -30.126330  127.410330   (-30.126330, 127.410330)           1
# 53       11.00 -76.276200  156.359390   (-76.276200, 156.359390)           1
# 2334      8.80 -76.901450  156.687380   (-76.901450, 156.687380)           1
# 950      10.00 -86.716670 -141.500000  (-86.716670, -141.500000)           1
# 4209   4440.00  12.900000    0.080000      (12.900000, 0.080000)           0
# 247       6.65 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 268       7.34 -72.995556   75.193056    (-72.995556, 75.193056)           1
# 4332   9000.00  46.050000    4.633330      (46.050000, 4.633330)           0
# 1453      3.48 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 4005   7000.00  43.750000    5.116670      (43.750000, 5.116670)           0
# 2797      2.90 -84.000000  168.000000   (-84.000000, 168.000000)           1
# 1295     21.30 -76.282980  156.478460   (-76.282980, 156.478460)           1
# 2578    434.00  18.335000   54.200000     (18.335000, 54.200000)           1
# 3480      3.17 -84.000000  168.000000   (-84.000000, 168.000000)           1
# 2798      6.59 -71.500000   35.666670    (-71.500000, 35.666670)           1
# 4001  37000.00  48.766670    0.633330      (48.766670, 0.633330)           0
# 3304   2300.00  34.666670 -102.000000   (34.666670, -102.000000)           1
#
#       year_1980s  year_1990s  year_2000s  year_2010_2020
# 3810           1           0           0               0
# 3707           0           0           0               0
# 1492           0           1           0               0
# 1082           0           0           0               0
# 3808           0           0           0               0
# 2551           0           0           1               0
# 3689           0           0           0               0
# 840            0           0           1               0
# 65             0           1           0               0
# 2425           1           0           0               0
# 3995           0           0           0               0
# 159            1           0           0               0
# 1040           0           0           0               0
# 60             0           0           1               0
# 2180           1           0           0               0
# 4098           0           1           0               0
# 3405           0           1           0               0
# 4145           0           0           0               0
# 2082           0           0           1               0
# 4037           0           0           0               0
# 2267           0           1           0               0
# 2653           0           1           0               0
# 1288           0           0           1               0
# 4449           0           0           0               0
# 586            0           0           1               0
# 4558           0           0           0               0
# 771            0           0           1               0
# 48             0           1           0               0
# 182            0           1           0               0
# 3815           0           1           0               0
# ...          ...         ...         ...             ...
# 609            0           0           1               0
# 818            0           1           0               0
# 3413           0           0           0               0
# 2555           0           0           1               0
# 3229           1           0           0               0
# 4361           0           0           0               0
# 2192           0           1           0               0
# 2654           0           1           0               0
# 2837           0           1           0               0
# 283            0           0           0               0
# 4159           0           0           1               0
# 593            1           0           0               0
# 2586           0           0           0               0
# 1628           0           1           0               0
# 53             0           1           0               0
# 2334           1           0           0               0
# 950            0           1           0               0
# 4209           0           0           1               0
# 247            0           0           0               0
# 268            0           0           1               0
# 4332           0           0           0               0
# 1453           0           0           0               0
# 4005           0           0           0               0
# 2797           0           1           0               0
# 1295           0           1           0               0
# 2578           0           0           1               0
# 3480           0           0           1               0
# 2798           0           0           0               0
# 4001           0           0           0               0
# 3304           1           0           0               0
#
# [4563 rows x 9 columns]

# %% [markdown]
# # Polygon

# %%
import geopandas as gpd

# %%
from shapely.geometry import Polygon

# %%
polygon_geom = Polygon(zip(dfsamp.reclong, dfsamp.reclat))
crs = {'init': 'epsg:4326'}
polygon = gpd.GeoDataFrame(index=[0], crs=crs, geometry=[polygon_geom])       
print(polygon.geometry)
# Out:
# 0    POLYGON ((11.03333 12.85, -97.58333 35.95, 16....
# Name: geometry, dtype: object

# %%
#polygon.to_file(filename='polygon.geojson', driver='GeoJSON')
#polygon.to_file(filename='polygon.shp', driver="ESRI Shapefile")

# %%
import folium
m = folium.Map([50.854457, 4.377184], zoom_start=5, tiles='cartodbpositron')
folium.GeoJson(polygon).add_to(m)
folium.LatLngPopup().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !pip install datapackage
# Out:
# Collecting datapackage
#   Using cached https://files.pythonhosted.org/packages/9d/83/46e4f7d7bdf3cc4fa76f0ab7e7db3a890ae1c98a88e143a7f0eae7d031be/datapackage-1.6.2-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema>=2.5 in /anaconda3/lib/python3.7/site-packages (from datapackage) (3.0.1)
# Requirement already satisfied: unicodecsv>=0.14 in /anaconda3/lib/python3.7/site-packages (from datapackage) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in /anaconda3/lib/python3.7/site-packages (from datapackage) (2.0)
# Collecting tabulator>=1.20 (from datapackage)
#   Using cached https://files.pythonhosted.org/packages/9f/0d/523058d853abf76bf97057eb498efaf2b4aca433cf9c2db11a6e04c1ebb1/tabulator-1.21.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.8 in /anaconda3/lib/python3.7/site-packages (from datapackage) (2.21.0)
# Collecting cchardet>=1.0 (from datapackage)
#   Using cached https://files.pythonhosted.org/packages/74/64/3988d388315c1af3e24f447689dadf30edead43366fb2041cb103380b57f/cchardet-2.1.4.tar.gz
# Requirement already satisfied: six>=1.10 in /anaconda3/lib/python3.7/site-packages (from datapackage) (1.12.0)
# Collecting tableschema>=1.1.0 (from datapackage)
#   Using cached https://files.pythonhosted.org/packages/a1/55/36de5a9c3cf6f615ddfcec5fc1b99dac393f09351ac2ffa4b18c9fbeb36b/tableschema-1.5.3-py2.py3-none-any.whl
# Requirement already satisfied: click>=6.7 in /anaconda3/lib/python3.7/site-packages (from datapackage) (7.0)
# Requirement already satisfied: attrs>=17.4.0 in /anaconda3/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /anaconda3/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (0.14.11)
# Requirement already satisfied: setuptools in /anaconda3/lib/python3.7/site-packages (from jsonschema>=2.5->datapackage) (40.8.0)
# Requirement already satisfied: jsonlines>=1.1 in /anaconda3/lib/python3.7/site-packages (from tabulator>=1.20->datapackage) (1.2.0)
# Requirement already satisfied: linear-tsv>=1.0 in /anaconda3/lib/python3.7/site-packages (from tabulator>=1.20->datapackage) (1.1.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in /anaconda3/lib/python3.7/site-packages (from tabulator>=1.20->datapackage) (1.3.1)
# Requirement already satisfied: ijson>=2.0 in /anaconda3/lib/python3.7/site-packages (from tabulator>=1.20->datapackage) (2.4)
# Requirement already satisfied: xlrd>=1.0 in /anaconda3/lib/python3.7/site-packages (from tabulator>=1.20->datapackage) (1.2.0)
# Requirement already satisfied: openpyxl<2.5,>=2.4 in /anaconda3/lib/python3.7/site-packages (from tabulator>=1.20->datapackage) (2.4.11)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=2.8->datapackage) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=2.8->datapackage) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=2.8->datapackage) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=2.8->datapackage) (2019.3.9)
# Requirement already satisfied: rfc3986>=1.1.0 in /anaconda3/lib/python3.7/site-packages (from tableschema>=1.1.0->datapackage) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.4 in /anaconda3/lib/python3.7/site-packages (from tableschema>=1.1.0->datapackage) (2.8.0)
# Requirement already satisfied: isodate>=0.5.4 in /anaconda3/lib/python3.7/site-packages (from tableschema>=1.1.0->datapackage) (0.6.0)
# Requirement already satisfied: jdcal in /anaconda3/lib/python3.7/site-packages (from openpyxl<2.5,>=2.4->tabulator>=1.20->datapackage) (1.4)
# Requirement already satisfied: et-xmlfile in /anaconda3/lib/python3.7/site-packages (from openpyxl<2.5,>=2.4->tabulator>=1.20->datapackage) (1.0.1)
# Building wheels for collected packages: cchardet
#   Building wheel for cchardet (setup.py) ... error
#   Complete output from command /anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-install-hkcf9u2g/cchardet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-wheel-rfbevs9_ --python-tag cp37:
#   cythonize: ['src/cchardet/_cchardet.pyx']
#   /anaconda3/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-install-hkcf9u2g/cchardet/src/cchardet/_cchardet.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.7
#   creating build/lib.macosx-10.7-x86_64-3.7/cchardet
#   copying src/cchardet/version.py -> build/lib.macosx-10.7-x86_64-3.7/cchardet
#   copying src/cchardet/__init__.py -> build/lib.macosx-10.7-x86_64-3.7/cchardet
#   running build_ext
#   building 'cchardet._cchardet' extension
#   creating build/temp.macosx-10.7-x86_64-3.7
#   creating build/temp.macosx-10.7-x86_64-3.7/src
#   creating build/temp.macosx-10.7-x86_64-3.7/src/cchardet
#   creating build/temp.macosx-10.7-x86_64-3.7/src/ext
#   creating build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet
#   creating build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src
#   creating build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/cchardet/_cchardet.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/cchardet/_cchardet.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/CharDistribution.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/CharDistribution.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/JpCntx.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/JpCntx.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangArabicModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangArabicModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangBulgarianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangBulgarianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangCroatianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCroatianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangCzechModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCzechModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangEsperantoModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEsperantoModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangEstonianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEstonianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangFinnishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFinnishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangFrenchModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFrenchModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangDanishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangDanishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangGermanModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGermanModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangGreekModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGreekModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangHungarianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHungarianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangHebrewModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHebrewModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangIrishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangIrishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangItalianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangItalianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangLithuanianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangLithuanianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangLatvianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangLatvianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangMalteseModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangMalteseModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangPolishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangPolishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangPortugueseModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangPortugueseModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangRomanianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangRomanianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangRussianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangRussianModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangSlovakModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSlovakModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangSloveneModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSloveneModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangSwedishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSwedishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangSpanishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSpanishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangThaiModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangThaiModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangTurkishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangTurkishModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangVietnameseModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangVietnameseModel.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsHebrewProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsHebrewProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsCharSetProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsCharSetProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsBig5Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsBig5Prober.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEUCJPProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCJPProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEUCKRProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCKRProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEUCTWProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCTWProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEscCharsetProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscCharsetProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEscSM.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscSM.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsGB2312Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsGB2312Prober.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsMBCSGroupProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSGroupProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsMBCSSM.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSSM.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsSBCSGroupProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCSGroupProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsSBCharSetProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCharSetProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsSJISProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSJISProber.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsUTF8Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUTF8Prober.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsLatin1Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsLatin1Prober.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsUniversalDetector.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUniversalDetector.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/uchardet.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/uchardet.o
#   warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#   1 warning generated.
#   g++ -bundle -undefined dynamic_lookup -L/anaconda3/lib -arch x86_64 -L/anaconda3/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.7-x86_64-3.7/src/cchardet/_cchardet.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/CharDistribution.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/JpCntx.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangArabicModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangBulgarianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCroatianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCzechModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEsperantoModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEstonianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFinnishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFrenchModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangDanishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGermanModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGreekModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHungarianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHebrewModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangIrishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangItalianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangLithuanianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangLatvianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangMalteseModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangPolishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangPortugueseModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangRomanianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangRussianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSlovakModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSloveneModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSwedishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSpanishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangThaiModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangTurkishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangVietnameseModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsHebrewProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsCharSetProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsBig5Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCJPProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCKRProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCTWProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscCharsetProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscSM.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsGB2312Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSGroupProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSSM.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCSGroupProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCharSetProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSJISProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUTF8Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsLatin1Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUniversalDetector.o bu ...
#   clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#   ld: library not found for -lstdc++
#   clang: error: linker command failed with exit code 1 (use -v to see invocation)
#   error: command 'g++' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for cchardet
#   Running setup.py clean for cchardet
# Failed to build cchardet
# Installing collected packages: cchardet, tabulator, tableschema, datapackage
#   Running setup.py install for cchardet ... error
#     Complete output from command /anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-install-hkcf9u2g/cchardet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-record-x0vhtqc_/install-record.txt --single-version-externally-managed --compile:
#     cythonize: ['src/cchardet/_cchardet.pyx']
#     /anaconda3/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-install-hkcf9u2g/cchardet/src/cchardet/_cchardet.pyx
#       tree = Parsing.p_module(s, pxd, full_module_name)
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.7
#     creating build/lib.macosx-10.7-x86_64-3.7/cchardet
#     copying src/cchardet/version.py -> build/lib.macosx-10.7-x86_64-3.7/cchardet
#     copying src/cchardet/__init__.py -> build/lib.macosx-10.7-x86_64-3.7/cchardet
#     running build_ext
#     building 'cchardet._cchardet' extension
#     creating build/temp.macosx-10.7-x86_64-3.7
#     creating build/temp.macosx-10.7-x86_64-3.7/src
#     creating build/temp.macosx-10.7-x86_64-3.7/src/cchardet
#     creating build/temp.macosx-10.7-x86_64-3.7/src/ext
#     creating build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet
#     creating build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src
#     creating build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/cchardet/_cchardet.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/cchardet/_cchardet.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/CharDistribution.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/CharDistribution.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/JpCntx.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/JpCntx.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangArabicModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangArabicModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangBulgarianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangBulgarianModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangCroatianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCroatianModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangCzechModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCzechModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangEsperantoModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEsperantoModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangEstonianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEstonianModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangFinnishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFinnishModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangFrenchModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFrenchModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangDanishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangDanishModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangGermanModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGermanModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangGreekModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGreekModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangHungarianModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHungarianModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangHebrewModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHebrewModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangIrishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangIrishModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
# ...
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangTurkishModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangTurkishModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/LangModels/LangVietnameseModel.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangVietnameseModel.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsHebrewProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsHebrewProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsCharSetProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsCharSetProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsBig5Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsBig5Prober.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEUCJPProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCJPProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEUCKRProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCKRProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEUCTWProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCTWProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEscCharsetProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscCharsetProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsEscSM.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscSM.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsGB2312Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsGB2312Prober.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsMBCSGroupProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSGroupProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsMBCSSM.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSSM.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsSBCSGroupProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCSGroupProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsSBCharSetProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCharSetProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsSJISProber.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSJISProber.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsUTF8Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUTF8Prober.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsLatin1Prober.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsLatin1Prober.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/nsUniversalDetector.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUniversalDetector.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -Isrc/ext/uchardet/src -I/anaconda3/include/python3.7m -c src/ext/uchardet/src/uchardet.cpp -o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/uchardet.o
#     warning: include path for stdlibc++ headers not found; pass '-stdlib=libc++' on the command line to use the libc++ standard library instead [-Wstdlibcxx-not-found]
#     1 warning generated.
#     g++ -bundle -undefined dynamic_lookup -L/anaconda3/lib -arch x86_64 -L/anaconda3/lib -arch x86_64 -arch x86_64 build/temp.macosx-10.7-x86_64-3.7/src/cchardet/_cchardet.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/CharDistribution.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/JpCntx.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangArabicModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangBulgarianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCroatianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangCzechModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEsperantoModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangEstonianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFinnishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangFrenchModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangDanishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGermanModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangGreekModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHungarianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangHebrewModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangIrishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangItalianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangLithuanianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangLatvianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangMalteseModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangPolishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangPortugueseModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangRomanianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangRussianModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSlovakModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSloveneModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSwedishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangSpanishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangThaiModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangTurkishModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/LangModels/LangVietnameseModel.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsHebrewProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsCharSetProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsBig5Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCJPProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCKRProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEUCTWProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscCharsetProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsEscSM.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsGB2312Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSGroupProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsMBCSSM.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCSGroupProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSBCharSetProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsSJISProber.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUTF8Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsLatin1Prober.o build/temp.macosx-10.7-x86_64-3.7/src/ext/uchardet/src/nsUniversalDetector.o  ...
#     clang: warning: libstdc++ is deprecated; move to libc++ with a minimum deployment target of OS X 10.9 [-Wdeprecated]
#     ld: library not found for -lstdc++
#     clang: error: linker command failed with exit code 1 (use -v to see invocation)
#     error: command 'g++' failed with exit status 1
#
#     ----------------------------------------
# Command "/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-install-hkcf9u2g/cchardet/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-record-x0vhtqc_/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /private/var/folders/xc/6t9f4xbd23x_54t00bpq4h0m0000gn/T/pip-install-hkcf9u2g/cchardet/

# %%
import requests

# %%
def example(latitude,longitude):
# grab some lat/long coords from wherever. For this example,
# I just opened a javascript console in the browser and ran:
#
# navigator.geolocation.getCurrentPosition(function(p) {
#   console.log(p);
# })
#
    #latitude = -84.00000 #35.1330343
    #longitude = 168.00000 #-90.0625056
# Did the geocoding request comes from a device with a
# location sensor? Must be either true or false.
    sensor = 'true'
# Hit Google's reverse geocoder directly
# NOTE: I *think* their terms state that you're supposed to
# use google maps if you use their api for anything.
    base = 
    params =.format(
lat=latitude,
lon=longitude,
sen=sensor
    )
    url = "{base}{params}".format(base=base, params=params)
    response = requests.get(url)
    return response.json()['results'][0]['address_components']

# %%
for i in example(dfsamp.reclat[109],dfsamp.reclong[109]) : 
    countries = []   
    countries.append(i['long_name'])
    print(countries)
# Out:
# ['Jufra District']
# ['Libya']

# %%
 for key,val in tt:
        test = []
        if (key == 'types') & ('country' == val): 
            #test.append(['long_name'])
            print(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-a3501c9117cd> in <module>
# ----> 1 for key,val in tt:
#       2        test = []
#       3        if (key == 'types') & ('country' == val):
#       4            #test.append(['long_name'])
#       5            print(True)
#
# NameError: name 'tt' is not defined

# %%
{k: v for k, v in ['address_components'].items() if v[0] countain and v[1] < 5}

# %%
example(44.383330,-68.750000)

# %%
for j in range(0,4563):
    for i in example(dfsamp.reclat[j],dfsamp.reclong[j]) : 
        countries = []
        countries.append(i['long_name'])
    print(countries)
# Out:
# ['Antarctica']
# ['Antarctica']
# ['79311']
# ['Antarctica']
# ['Libya']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['92356']
# ['64434']
# ['Oman']
# ['Oman']
# ['Antarctica']
# ['United States']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Libya']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['5690']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Chile']
# ['Antarctica']
# ['Libya']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['78945']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Chile']
# ['79052']
# ['Oman']
# ['Antarctica']
# ['Libya']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Ukraine']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Algeria']
# ['Antarctica']
# ['Antarctica']
# ['Libya']
# ['Antarctica']
# ['Antarctica']
# ['Chile']
# ['Antarctica']
# ['Antarctica']
# ['Algeria']
# ['Morocco']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['6431']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Libya']
# ['Chile']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Chile']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Chile']
# ['1776']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Algeria']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['P1103']
# ['6051']
# ['Libya']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['8032']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Algeria']
# ['Chile']
# ['Morocco']
# ['Antarctica']
# ['Antarctica']
# ['Chile']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Libya']
# ['Antarctica']
# ['6434']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Tunisia']
# ['Oman']
# ['Libya']
# ['Antarctica']
# ['26190']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['29126']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Algeria']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['85342']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['79042']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Morocco']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['South Africa']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['7682']
# ['Libya']
# ['Oman']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['6431']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Antarctica']
# ['Antarctica']
# ['Antarctica']
# ['Morocco']
# ['Chile']
# ['Antarctica']
# ['Antarctica']
# ['Oman']
# ['Libya']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-87-31726b169a91> in <module>
#       1 for j in range(0,4563):
# ----> 2     for i in example(dfsamp.reclat[j],dfsamp.reclong[j]) :
#       3         countries = []
#       4         countries.append(i['long_name'])
#       5     print(countries)
#
# <ipython-input-83-c6100fda3f71> in example(latitude, longitude)
#      23     url = "{base}{params}".format(base=base, params=params)
#      24     response = requests.get(url)
# ---> 25     return response.json()['results'][0]['address_components']
#
# IndexError: list index out of range

# %%
dfsamp.shape

# %%
# !pip install geopy

# %%
dfsamp.GeoLocation
