# %%
# librairies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import geopandas as gpd
 #as gdp
#from mpl_toolkits.basemap import basemap # library to plot maps

# %%
import geoplot

# %%
# open the file
df = pd.read_csv('meteorite-landings.csv')
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
df.shape
#(45716, 10) 
#(45424, 10) drop rows if NaN in year and select only year>=860 & year<=2016 (kaggle)
#(45309, 10) drop rows if Nan in mass
#(31705, 10) clean longitude & latitude columns (kaggle)
# Out:
# (31705, 10)

# %%
df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass           float64
# fall            object
# year           float64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %% [markdown]
# # clean the data

# %%
df.isna().sum()
# Out:
# name           0
# id             0
# nametype       0
# recclass       0
# mass           0
# fall           0
# year           0
# reclat         0
# reclong        0
# GeoLocation    0
# dtype: int64

# %%
# clean year's column
df = df[np.isfinite(df['year'])]
df = df[(df.year >=860) & (df.year <=2016)]
pd.to_numeric(df.year,downcast='integer')
# Out:
# 0        1880
# 1        1951
# 2        1952
# 3        1976
# 4        1902
# 5        1919
# 6        1949
# 7        1814
# 8        1930
# 9        1920
# 10       1974
# 11       1925
# 12       1769
# 13       1949
# 14       1838
# 15       1959
# 16       1981
# 17       1957
# 18       2001
# 19       1806
# 20       1766
# 21       1949
# 22       2002
# 23       1835
# 24       1873
# 25       1860
# 26       1900
# 27       1883
# 28       1899
# 29       1969
#          ...
# 45685    2006
# 45686    1914
# 45687    2011
# 45688    2011
# 45689    2011
# 45690    1946
# 45691    1792
# 45692    1969
# 45693    1919
# 45694    1999
# 45695    1987
# 45696    1998
# 45697    1998
# 45698    1930
# 45699    1984
# 45701    1998
# 45702    2002
# 45703    1955
# 45704    1973
# 45705    1967
# 45706    1956
# 45707    1983
# 45708    1966
# 45709    1981
# 45710    1990
# 45711    1990
# 45712    1999
# 45713    1939
# 45714    2003
# 45715    1976
# Name: year, Length: 45424, dtype: int16

# %%
# columns with 2 values :
df.fall.value_counts(normalize=True)
# Out:
# Found    0.97563
# Fell     0.02437
# Name: fall, dtype: float64

# %%
df.nametype.value_counts(normalize=True)
# Out:
# Valid     0.998371
# Relict    0.001629
# Name: nametype, dtype: float64

# %%
# clean mass's column
df = df[np.isfinite(df['mass'])]

# %%
# clean reclat's & reclong's columns 
df = df[(df.reclat != 0.0) & (df.reclong != 0.0)]
df = df[(df.reclong <=180) & (df.reclong >=-180)]

# %%
df = df[np.isfinite(df['reclat'])]

# %% [markdown]
# # Descriptive stats and visualisation

# %%
df.describe()
# Out:
#                  id          mass          year        reclat       reclong
# count  31705.000000  3.170500e+04  31705.000000  31705.000000  31705.000000
# mean   20751.653272  1.867359e+04   1987.087084    -47.602009     73.452607
# std    14974.205352  6.892699e+05     26.791228     46.714171     83.419083
# min        1.000000  0.000000e+00    860.000000    -87.366670   -165.433330
# 25%     9190.000000  6.530000e+00   1983.000000    -79.683330     26.000000
# 50%    18511.000000  3.007000e+01   1991.000000    -72.000000     57.147030
# 75%    27300.000000  2.050000e+02   2000.000000     18.393170    159.414820
# max    57455.000000  6.000000e+07   2013.000000     81.166670    178.200000

# %%
df2.boxplot()

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.scatter(df3['year'], df3['mass'])
ax.set_ylabel('mass of meteorite')
ax.set_xlabel('year')
plt.show()

# %%
stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#             count          mean            std        min         25%  \
# id        31705.0  20751.653272   14974.205352    1.00000  9190.00000
# nametype  31705.0      0.999338       0.025728    0.00000     1.00000
# mass      31705.0  18673.585234  689269.886629    0.00000     6.53000
# fall      31705.0      0.966472       0.180013    0.00000     1.00000
# year      31705.0   1987.087084      26.791228  860.00000  1983.00000
# reclat    31705.0    -47.602009      46.714171  -87.36667   -79.68333
# reclong   31705.0     73.452607      83.419083 -165.43333    26.00000
#
#                   50%          75%           max          IQR
# id        18511.00000  27300.00000  5.745500e+04  18110.00000
# nametype      1.00000      1.00000  1.000000e+00      0.00000
# mass         30.07000    205.00000  6.000000e+07    198.47000
# fall          1.00000      1.00000  1.000000e+00      0.00000
# year       1991.00000   2000.00000  2.013000e+03     17.00000
# reclat      -72.00000     18.39317  8.116667e+01     98.07650
# reclong      57.14703    159.41482  1.782000e+02    133.41482

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df2 = remove_outlier(df,'mass')

# %%
df3['year'].hist()

# %%
df3 = df[(df.year >=1800) & (df.year <=2016)]

# %%
plt.subplot(211)
df.year.hist(bins=np.arange(1900,2014,1),figsize=(8,7))
plt.title('Discoveries per year 1900-2014')
plt.xlim(1900,2014)
# Out:
# (1900, 2014)

# %%
fall_mean = dum[["found", "fell"]].groupby(["year"]).agg("mean")
fall_mean.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-201-89b69049f84e> in <module>
# ----> 1 fall_mean = dum[["found", "fell"]].groupby(["year"]).agg("mean")
#       2 fall_mean.plot.bar()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     576                 in_axis, name, level, gpr = False, None, gpr, None
#     577             else:
# --> 578                 raise KeyError(gpr)
#     579         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     580             # Add key to exclusions
#
# KeyError: 'year'

# %%
df.corr()
# Out:
#                 id  nametype      mass      fall      year    reclat   reclong
# id        1.000000 -0.052221 -0.014712  0.053076  0.238671  0.056363 -0.183254
# nametype -0.052221  1.000000  0.000697 -0.004795 -0.016436 -0.045768  0.010203
# mass     -0.014712  0.000697  1.000000 -0.007814 -0.124215  0.036230 -0.027062
# fall      0.053076 -0.004795 -0.007814  1.000000  0.508986 -0.310099  0.118656
# year      0.238671 -0.016436 -0.124215  0.508986  1.000000 -0.229160  0.197239
# reclat    0.056363 -0.045768  0.036230 -0.310099 -0.229160  1.000000 -0.534294
# reclong  -0.183254  0.010203 -0.027062  0.118656  0.197239 -0.534294  1.000000

# %%
sns.heatmap(df.corr(),cmap="YlGnBu",annot=True)
#seems a correlation between fall & year

# %%
# fall : dummies

# %%
def dummies(val):
    if val == 'Fell':
        val = 0
    elif val == 'Found':
        val = 1
    return val
df['fall'] = df['fall'].apply(lambda val : dummies(val) if pd.isnull(val) == False else np.nan)

# %%
df.head()
# Out:
#        name   id nametype     recclass      mass  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0     0  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0     0  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0     0  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0     0  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0     0  1902.0 -33.16667
#
#      reclong               GeoLocation
# 0    6.08333     (50.775000, 6.083330)
# 1   10.23333    (56.183330, 10.233330)
# 2 -113.00000  (54.216670, -113.000000)
# 3  -99.90000   (16.883330, -99.900000)
# 4  -64.95000  (-33.166670, -64.950000)

# %%
# not relevant
def dummies2(val):
    if val == 'Relict':
        val = 0
    elif val == 'Valid':
        val = 1
    return val
df['nametype'] = df['nametype'].apply(lambda val : dummies2(val) if pd.isnull(val) == False else np.nan)

# %%
df.fall.value_counts().plot.bar()
plt.title('Fall')
plt.xlabel('Found = 1 & Fall = 0')
#plt.ylabel('ylabel')
#plt.legend(['Meteorites Found','Meteorites Seen Falling']) ?
plt.show()
## pas assez de données

# %%
g = sns.FacetGrid(df, col="fall")
g = g.map(plt.hist, "year", color="c")

# %%
'''
geometry = [Point(float(x), float(y)) for x, y in zip(df.reclong, df.reclat)]
'''

# %%
from mpl_toolkits.basemap import Basemap

# %%
# MAP OF ALL IMPACTS
fig, ax = plt.subplots(figsize = (15, 10))
map = Basemap(projection='cyl')
map.drawmapboundary(fill_color='w')
map.drawcoastlines(linewidth=0.5)
map.drawmeridians(range(0, 360, 20),linewidth=0.1)
map.drawparallels([-66.56083,-23.5,0.0,23.5,66.56083], linewidth=0.6) 
#plotting equator and tropics and polar circles

x, y = map(df.reclong,df.reclat)

map.scatter(x, y, marker='.',alpha=0.25,c='green',edgecolor='None')
plt.title('Map of all impacts', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Map of all impacts')

# %%
# MAP OF FOUND OR FELL METEORITES
fig, ax = plt.subplots(figsize = (20, 15))
map = Basemap(projection='cyl')
map.drawmapboundary(fill_color='w')
map.drawcoastlines(linewidth=0.5)
map.drawmeridians(range(0, 360, 20),linewidth=0.1)
map.drawparallels([-66.56083,-23.5,0.0,23.5,66.56083], linewidth=0.6) 
#plotting equator and tropics and polar circles

x1, y1 = map(df[df.fall == 0].reclong,df[df.fall == 0].reclat)
map.scatter(x1, y1, marker='.',alpha=0.25,c='green',edgecolor='None')

x1, y1 = map(df[df.fall == 1].reclong,df[df.fall == 1].reclat)
map.scatter(x1, y1, marker='.',alpha=0.25,c='red',edgecolor='None')
#plt.legend()
plt.title('Map of all impacts', fontsize=15)
plt.show()

# %%
# MAP OF FOUND OR FELL METEORITES
fig, ax = plt.subplots(figsize = (20, 15))
map = Basemap(projection='cyl')
map.drawmapboundary(fill_color='w')
map.drawcoastlines(linewidth=0.5)
map.drawmeridians(range(0, 360, 20),linewidth=0.1)
map.drawparallels([-66.56083,-23.5,0.0,23.5,66.56083], linewidth=0.6) 
#plotting equator and tropics and polar circles

x1, y1 = map(df[df.fall == 0].reclong,df[df.fall == 0].reclat)
map.scatter(x1, y1, marker='.',alpha=0.25,c='green',edgecolor='None')

x1, y1 = map(df[df.fall == 1].reclong,df[df.fall == 1].reclat)
map.scatter(x1, y1, marker='.',alpha=0.25,c='red',edgecolor='None')
#plt.legend()
plt.title('Map of all impacts', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None,
            width=8E6, height=8E6, 
            lat_0=45, lon_0=-100,)
m.etopo(scale=0.5, alpha=0.5)

# Map (long, lat) to (x, y) for plotting
x, y = m(df.reclong,df.reclat)
plt.scatter(x, y)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pyproj/__init__.py in _copytobuffer(x)
#     544                 # (deal with input array in fortran order)
# --> 545                 inx = x.copy(order="C").astype('d')
#     546                 # inx,isfloat,islist,istuple
#
# TypeError: copy() got an unexpected keyword argument 'order'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pyproj/__init__.py in _copytobuffer(x)
#     551                     # i don't know Numeric/numarrays has `shape'.
# --> 552                     x.typecode()
#     553                     inx = x.astype('d')
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#
# AttributeError: 'Series' object has no attribute 'typecode'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-7507daedd3cf> in <module>
#       6
#       7 # Map (long, lat) to (x, y) for plotting
# ----> 8 x, y = m(df.reclong,df.reclat)
#       9 plt.scatter(x, y)
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/__init__.py in __call__(self, x, y, inverse)
#    1189             except TypeError:
#    1190                 y = [_dg2rad*yy for yy in y]
# -> 1191         xout,yout = self.projtran(x,y,inverse=inverse)
#    1192         if self.celestial and inverse:
#    1193             try:
#
# /anaconda3/lib/python3.7/site-packages/mpl_toolkits/basemap/proj.py in __call__(self, *args, **kw)
#     286             outxy = self._proj4(xy, inverse=inverse)
#     287         else:
# --> 288             outx,outy = self._proj4(x, y, inverse=inverse)
#     289         if inverse:
#     290             if self.projection in ['merc','mill','gall']:
#
# /anaconda3/lib/python3.7/site-packages/pyproj/__init__.py in __call__(self, *args, **kw)
#     391         lon, lat = args
#     392         # process inputs, making copies that support buffer API.
# --> 393         inx, xisfloat, xislist, xistuple = _copytobuffer(lon)
#     394         iny, yisfloat, yislist, yistuple = _copytobuffer(lat)
#     395         # call proj4 functions. inx and iny modified in place.
#
# /anaconda3/lib/python3.7/site-packages/pyproj/__init__.py in _copytobuffer(x)
#     555                     return inx,False,False,False
#     556                 except:
# --> 557                     raise TypeError('input must be an array, list, tuple or scalar')
#     558     else:
#     559         # perhaps they are regular python arrays?
#
# TypeError: input must be an array, list, tuple or scalar

# %%
map = Basemap(projection='cyl',llcrnrlat=10,llcrnrlon=-20,urcrnrlat=50,urcrnrlon=40,resolution='c')
map.etopo()
map.drawcountries()

map.scatter(df.reclong,df.reclat,edgecolor='none',color='k',alpha=0.5)
map.scatter(df.reclong,df.reclat,edgecolor='none',color='m',alpha=0.5)

plt.title('Comparison between meteorites found (magenta) and meteorites seen fallin (black)', fontsize=15)
plt.show()

# %%
#dum = pd.get_dummies(df3, columns=['fall'])
dum
# Out:
#                       name     id  nametype              recclass       mass  \
# 0                   Aachen      1         1                    L5       21.0
# 1                   Aarhus      2         1                    H6      720.0
# 2                     Abee      6         1                   EH4   107000.0
# 3                 Acapulco     10         1           Acapulcoite     1914.0
# 4                  Achiras    370         1                    L6      780.0
# 5                 Adhi Kot    379         1                   EH4     4239.0
# 6      Adzhi-Bogdo (stone)    390         1                 LL3-6      910.0
# 7                     Agen    392         1                    H5    30000.0
# 8                   Aguada    398         1                    L6     1620.0
# 9            Aguila Blanca    417         1                     L     1440.0
# 10        Aioun el Atrouss    423         1          Diogenite-pm     1000.0
# 11                     Aïr    424         1                    L6    24000.0
# 13                   Akaba    426         1                    L6      779.0
# 14                Akbarpur    427         1                    H4     1800.0
# 15                 Akwanga    432         1                     H     3000.0
# 16                 Akyumak    433         1             Iron, IVA    50000.0
# 17                 Al Rais    446         1                CR2-an      160.0
# 18               Al Zarnkh    447         1                   LL5      700.0
# 19                   Alais    448         1                   CI1     6000.0
# 21                 Alberta    454         1                     L      625.0
# 22         Alby sur Chéran    458         1         Eucrite-mmict      252.0
# 23               Aldsworth    461         1                   LL5      700.0
# 24                  Aleppo    462         1                    L6     3200.0
# 25             Alessandria    463         1                    H5      908.0
# 26           Alexandrovsky    465         1                    H4     9251.0
# 27              Alfianello    466         1                    L6   228000.0
# 28                 Allegan   2276         1                    H5    32000.0
# 29                 Allende   2278         1                   CV3  2000000.0
# 30          Almahata Sitta  48915         1           Ureilite-an     3950.0
# 31              Alta'ameem   2284         1                   LL5     6000.0
# ...                    ...    ...       ...                   ...        ...
# 45682     Yorktown (Texas)  30371         1                    H5     3500.0
# 45683              Youanmi  30373         1           Iron, IIIAB   118400.0
# 45684            Youndegin  30374         1          Iron, IAB-MG  3800000.0
# 45685                Youxi  55793         1        Mesosiderite-C   218000.0
# 45686               Ysleta  30375         1       Iron, ungrouped   140700.0
# 45687            Yucca 015  57175         1               H-metal        3.0
# 45688            Yucca 016  57158         1                    H5       25.9
# 45689            Yucca 017  57159         1                    H5      200.0
# 45690               Yudoma  30376         1             Iron, IVA     7600.0
# 45693               Zaffra  30383         1          Iron, IAB-MG     3000.0
# 45694              Zag (b)  30385         1             Winonaite      300.0
# 45695               Zagora  30387         1         Iron, IAB-ung    50000.0
# 45696            Zakłodzie  30390         1        Enst achon-ung     8680.0
# 45697           Zapaliname  30392         1          Iron, IAB-MG    85000.0
# 45699   Zapotitlán Salinas  30394         1                    L4       27.7
# 45701               Zegdou  30398         1                    H3     6700.0
# 45702              Zelfana  31353         1                    L5     1058.0
# 45703                Zenda  30400         1     Iron, IAB complex     3700.0
# 45704                Zerga  30402         1                   LL6       76.0
# 45705             Zerhamra  30403         1        Iron, IIIAB-an   630000.0
# 45706              Zerkaly  31354         1                    H5    16000.0
# 45707             Zhaoping  54609         1     Iron, IAB complex  2000000.0
# 45708             Zhigansk  30405         1           Iron, IIIAB   900000.0
# 45709           Zhongxiang  30406         1                  Iron   100000.0
# 45710           Zillah 001  31355         1                    L6     1475.0
# 45711           Zillah 002  31356         1               Eucrite      172.0
# 45712               Zinder  30409         1  Pallasite, ungrouped       46.0
# 45713                 Zlin  30410         1                    H4        3.3
# 45714            Zubkovsky  31357         1                    L6     2167.0
# 45715           Zulu Queen  30414         1                  L3.7      200.0
#
#          year    reclat    reclong               GeoLocation  found  fell
# 0      1880.0  50.77500    6.08333     (50.775000, 6.083330)      1     0
# 1      1951.0  56.18333   10.23333    (56.183330, 10.233330)      1     0
# 2      1952.0  54.21667 -113.00000  (54.216670, -113.000000)      1     0
# 3      1976.0  16.88333  -99.90000   (16.883330, -99.900000)      1     0
# 4      1902.0 -33.16667  -64.95000  (-33.166670, -64.950000)      1     0
# 5      1919.0  32.10000   71.80000    (32.100000, 71.800000)      1     0
# 6      1949.0  44.83333   95.16667    (44.833330, 95.166670)      1     0
# 7      1814.0  44.21667    0.61667     (44.216670, 0.616670)      1     0
# 8      1930.0 -31.60000  -65.23333  (-31.600000, -65.233330)      1     0
# 9      1920.0 -30.86667  -64.55000  (-30.866670, -64.550000)      1     0
# 10     1974.0  16.39806   -9.57028    (16.398060, -9.570280)      1     0
# 11     1925.0  19.08333    8.38333     (19.083330, 8.383330)      1     0
# 13     1949.0  29.51667   35.05000    (29.516670, 35.050000)      1     0
# 14     1838.0  29.71667   77.95000    (29.716670, 77.950000)      1     0
# 15     1959.0   8.91667    8.43333      (8.916670, 8.433330)      1     0
# 16     1981.0  39.91667   42.81667    (39.916670, 42.816670)      1     0
# 17     1957.0  24.41667   39.51667    (24.416670, 39.516670)      1     0
# 18     2001.0  13.66033   28.96000    (13.660330, 28.960000)      1     0
# 19     1806.0  44.11667    4.08333     (44.116670, 4.083330)      1     0
# 21     1949.0   2.00000   22.66667     (2.000000, 22.666670)      1     0
# 22     2002.0  45.82133    6.01533     (45.821330, 6.015330)      1     0
# 23     1835.0  51.78333   -1.78333    (51.783330, -1.783330)      1     0
# 24     1873.0  36.23333   37.13333    (36.233330, 37.133330)      1     0
# 25     1860.0  44.88333    8.75000     (44.883330, 8.750000)      1     0
# 26     1900.0  50.95000   31.81667    (50.950000, 31.816670)      1     0
# 27     1883.0  45.26667   10.15000    (45.266670, 10.150000)      1     0
# 28     1899.0  42.53333  -85.88333   (42.533330, -85.883330)      1     0
# 29     1969.0  26.96667 -105.31667  (26.966670, -105.316670)      1     0
# 30     2008.0  20.74575   32.41275    (20.745750, 32.412750)      1     0
# 31     1977.0  35.27333   44.21556    (35.273330, 44.215560)      1     0
# ...       ...       ...        ...                       ...    ...   ...
# 45682  1957.0  28.95000  -97.40278   (28.950000, -97.402780)      0     1
# 45683  1917.0 -29.50000  118.75000  (-29.500000, 118.750000)      0     1
# 45684  1884.0 -32.10000  117.71667  (-32.100000, 117.716670)      0     1
# 45685  2006.0  26.06000  118.01000   (26.060000, 118.010000)      0     1
# 45686  1914.0  31.65000 -106.18333  (31.650000, -106.183330)      0     1
# 45687  2011.0  34.81970 -114.27610  (34.819700, -114.276100)      0     1
# 45688  2011.0  34.82658 -114.27763  (34.826580, -114.277630)      0     1
# 45689  2011.0  34.81923 -114.27735  (34.819230, -114.277350)      0     1
# 45690  1946.0  60.00000  140.00000   (60.000000, 140.000000)      0     1
# 45693  1919.0  35.00000  -94.75000   (35.000000, -94.750000)      0     1
# 45694  1999.0  27.33333   -9.33333    (27.333330, -9.333330)      0     1
# 45695  1987.0  30.36667   -5.85000    (30.366670, -5.850000)      0     1
# 45696  1998.0  50.76278   22.86611    (50.762780, 22.866110)      0     1
# 45697  1998.0  25.00944 -100.75000  (25.009440, -100.750000)      0     1
# 45699  1984.0  18.33333  -97.50000   (18.333330, -97.500000)      0     1
# 45701  1998.0  29.75000   -4.50000    (29.750000, -4.500000)      0     1
# 45702  2002.0  32.15833    4.63333     (32.158330, 4.633330)      0     1
# 45703  1955.0  42.51333  -88.48944   (42.513330, -88.489440)      0     1
# 45704  1973.0  20.25000  -12.68333   (20.250000, -12.683330)      0     1
# 45705  1967.0  29.85861   -2.64500    (29.858610, -2.645000)      0     1
# 45706  1956.0  52.13333   81.96667    (52.133330, 81.966670)      0     1
# 45707  1983.0  24.23333  111.18333   (24.233330, 111.183330)      0     1
# 45708  1966.0  68.00000  128.30000   (68.000000, 128.300000)      0     1
# 45709  1981.0  31.20000  112.50000   (31.200000, 112.500000)      0     1
# 45710  1990.0  29.03700   17.01850    (29.037000, 17.018500)      0     1
# 45711  1990.0  29.03700   17.01850    (29.037000, 17.018500)      0     1
# 45712  1999.0  13.78333    8.96667     (13.783330, 8.966670)      0     1
# 45713  1939.0  49.25000   17.66667    (49.250000, 17.666670)      0     1
# 45714  2003.0  49.78917   41.50460    (49.789170, 41.504600)      0     1
# 45715  1976.0  33.98333 -115.68333  (33.983330, -115.683330)      0     1
#
# [31658 rows x 11 columns]

# %%
dum.columns = dum.columns.str.replace('fall_0','found').str.replace('fall_1','fell')

# %%
dum.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'year', 'reclat',
#        'reclong', 'GeoLocation', 'found', 'fell'],
#       dtype='object')
